# %%
from openpyxl import Workbook

# %%
file_path = "D:\Github\python-coding-stuff\01_handling_excel\00_dataset\02_writing\test_file_1.xlsx"
file_name = 'test_file_1.xlsx'

workbook = Workbook()

# Note: we can also change the saving path 
workbook.save(filename=file_name)

# %%
file_path = r"D:\Github\python-coding-stuff\01_handling_excel\00_dataset\02_writing\test_file_1.xlsx"
file_name = 'test_file_1.xlsx'

workbook = Workbook()

# Note: we cannot change the saving path 
workbook.save(file_path)
