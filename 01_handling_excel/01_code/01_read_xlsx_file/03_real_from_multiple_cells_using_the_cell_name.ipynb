# %%
import openpyxl

# %%
# Give the location of the file 
file_path = r"D:\Github\python-coding-stuff\01_handling_excel\00_dataset\01_reading\test_file_1.xlsx"
wb_obj = openpyxl.load_workbook(file_path)

sheet_obj = wb_obj.active 

cell_obj = sheet_obj['A1': 'B6']

for cell1, cell2 in cell_obj: 
    print(cell1.value, cell2.value)
# Out:
# Name Course
# Ankit B.Tech
# Rahul M.Tech
# Priya MBA
# Nikhil B.Tech
# Nisha B.Tech

# %%
# Give the location of the file 
file_path = r"D:\Github\python-coding-stuff\01_handling_excel\00_dataset\01_reading\test_file_1.xlsx"
wb_obj = openpyxl.load_workbook(file_path)

sheet_obj = wb_obj.active 

cell_obj = sheet_obj['A1': 'B5']

for cell1, cell2 in cell_obj: 
    print(cell1.value, cell2.value)
# Out:
# Name Course
# Ankit B.Tech
# Rahul M.Tech
# Priya MBA
# Nikhil B.Tech
